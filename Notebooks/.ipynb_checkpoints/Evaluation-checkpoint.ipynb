# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Dataset

# %%
evaluation = pd.read_csv("../src/data/Evaluation_20_02_2022_12_06_15.csv")

# %% [markdown]
# # Inspecting Dataset

# %%
evaluation
# Out:
#    Unnamed: 0  index  Mean Squared Error  Mean Squared Error dB  \
# 0           0    0.0            0.000398             -34.006536
# 1           1    1.0            0.000400             -33.977523
# 2           2    2.0            0.000405             -33.927597
# 3           3    3.0            0.000405             -33.921884
# 4           4    4.0            0.000408             -33.896013
# 5           5    5.0            0.000413             -33.836556
#
#    Error in Filter Std  Occlusion Start  Occlusion End  Occlusion Duration  \
# 0            85.320931            100.0          100.0                 0.0
# 1            85.037575            100.0          130.0                30.0
# 2            85.031416            100.0          160.0                60.0
# 3            85.123814            100.0          190.0                90.0
# 4            85.006776            100.0          220.0               120.0
# 5            84.957497            100.0          250.0               150.0
#
#    System Noise  Meaned Filter Variance  Occlusion Duration(s)
# 0           0.5                0.012181                   0.00
# 1           0.5                0.012190                   0.25
# 2           0.5                0.012220                   0.50
# 3           0.5                0.012229                   0.75
# 4           0.5                0.012245                   1.00
# 5           0.5                0.012292                   1.25

# %% [markdown]
# ## Adding Occlusion in Time not in Samples

# %%
evaluation['Occlusion Duration(s)'] = evaluation['Occlusion Duration']*1/120

# %% [markdown]
# ## Plotting Data
# Plotting Mean Squared Error per Occlusion

# %%
plt.figure(figsize=(15, 10))
plt.title("Mean Squared Error per Occlusion Duration")
plt.plot(evaluation["Occlusion Duration(s)"], evaluation["Mean Squared Error dB"], marker='o')
plt.xlabel("Occlusion Duration (s)")

for x,y in zip(evaluation["Occlusion Duration(s)"].values,evaluation["Mean Squared Error dB"].values):
    label = "{:.2f} dB".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center


plt.show()

# %% [markdown]
# Plotting Meaned Filter Variance per Occlusion

# %%
plt.figure(figsize=(15, 10))
plt.title("Mean Filter Variance per Occlusion Duration")
plt.plot(evaluation["Occlusion Duration(s)"], evaluation["Meaned Filter Variance"], marker='o')
plt.xlabel("Occlusion Duration (s)")

for x,y in zip(evaluation["Occlusion Duration(s)"].values,evaluation["Meaned Filter Variance"].values):
    label = "{:.5f} ".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center


plt.show()
