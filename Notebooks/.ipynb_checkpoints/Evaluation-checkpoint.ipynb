# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Dataset

# %%
#First Okay run evaluation = pd.read_csv("../src/data/Evaluation_21_02_2022_17_41_47.csv")
evaluation = pd.read_csv("../src/data/Evaluation_good_002.csv")

# %% [markdown]
# # Inspecting Dataset

# %%
evaluation
# Out:
#     Unnamed: 0  index  Mean Squared Error  Mean Squared Error dB  \
# 0            0    0.0            0.000063             -42.006439
# 1            1    1.0            0.000095             -40.222714
# 2            2    2.0            0.000309             -35.101753
# 3            3    3.0            0.000787             -31.038408
# 4            4    4.0            0.001645             -27.837113
# 5            5    5.0            0.003019             -25.201847
# 6            6    6.0            0.004754             -23.229268
# 7            7    7.0            0.006593             -21.809378
# 8            8    8.0            0.008189             -20.867451
# 9            9    9.0            0.009185             -20.369430
# 10          10   10.0            0.009750             -20.110080
# 11          11   11.0            0.010582             -19.754157
# 12          12   12.0            0.012515             -19.025851
# 13          13   13.0            0.014872             -18.276410
# 14          14   14.0            0.018429             -17.345028
# 15          15   15.0            0.023097             -16.364419
# 16          16   16.0            0.040419             -13.934181
# 17          17   17.0            0.040419             -13.934181
# 18          18   18.0            0.040419             -13.934181
# 19          19   19.0            0.040419             -13.934181
# 20          20   20.0            0.040419             -13.934181
# 21          21   21.0            0.040419             -13.934181
# 22          22   22.0            0.040419             -13.934181
# 23          23   23.0            0.040419             -13.934181
# 24          24   24.0            0.040419             -13.934181
# 25          25   25.0            0.040419             -13.934181
# 26          26   26.0            0.040419             -13.934181
# 27          27   27.0            0.040419             -13.934181
# 28          28   28.0            0.040419             -13.934181
# 29          29   29.0            0.040419             -13.934181
#
#     Error in Filter Std  Occlusion Start  Occlusion End  Occlusion Duration  \
# 0             96.605889           1000.0         1000.0                 0.0
# 1             96.341013           1000.0         1300.0               300.0
# 2             95.922139           1000.0         1600.0               600.0
# 3             95.330787           1000.0         1900.0               900.0
# 4             94.240483           1000.0         2200.0              1200.0
# 5             94.203523           1000.0         2500.0              1500.0
# 6             93.328816           1000.0         2800.0              1800.0
# 7             92.497228           1000.0         3100.0              2100.0
# 8             92.201552           1000.0         3400.0              2400.0
# 9             92.029075           1000.0         3700.0              2700.0
# 10            92.041395           1000.0         4000.0              3000.0
# 11            92.041395           1000.0         4300.0              3300.0
# 12            92.041395           1000.0         4600.0              3600.0
# 13            91.628681           1000.0         4900.0              3900.0
# 14            92.047555           1000.0         5200.0              4200.0
# 15            92.029075           1000.0         5500.0              4500.0
# 16            27.202168           1000.0         5800.0              4800.0
# 17            27.202168           1000.0         6100.0              5100.0
# 18            27.202168           1000.0         6400.0              5400.0
# 19            27.202168           1000.0         6700.0              5700.0
# 20            27.202168           1000.0         7000.0              6000.0
# 21            27.202168           1000.0         7300.0              6300.0
# 22            27.202168           1000.0         7600.0              6600.0
# 23            27.202168           1000.0         7900.0              6900.0
# 24            27.202168           1000.0         8200.0              7200.0
# 25            27.202168           1000.0         8500.0              7500.0
# 26            27.202168           1000.0         8800.0              7800.0
# 27            27.202168           1000.0         9100.0              8100.0
# 28            27.202168           1000.0         9400.0              8400.0
# 29            27.202168           1000.0         9700.0              8700.0
#
#     System Noise  Meaned Filter Variance  Filter Crashed  Crashed At
# 0            0.5                0.001878             0.0         0.0
# 1            0.5                0.002197             0.0         0.0
# 2            0.5                0.003157             0.0         0.0
# 3            0.5                0.005059             0.0         0.0
# 4            0.5                0.008418             0.0         0.0
# 5            0.5                0.013991             0.0         0.0
# 6            0.5                0.022814             0.0         0.0
# 7            0.5                0.036216             0.0         0.0
# 8            0.5                0.056628             0.0         0.0
# 9            0.5                0.087987             0.0         0.0
# 10           0.5                0.138544             0.0         0.0
# 11           0.5                0.229947             0.0         0.0
# 12           0.5                0.419305             0.0         0.0
# 13           0.5                0.769025             0.0         0.0
# 14           0.5                1.152277             0.0         0.0
# 15           0.5                6.116453             0.0         0.0
# 16           0.5              143.602013             1.0      5504.0
# 17           0.5              143.602013             1.0      5504.0
# 18           0.5              143.602013             1.0      5504.0
# 19           0.5              143.602013             1.0      5504.0
# 20           0.5              143.602013             1.0      5504.0
# 21           0.5              143.602013             1.0      5504.0
# 22           0.5              143.602013             1.0      5504.0
# 23           0.5              143.602013             1.0      5504.0
# 24           0.5              143.602013             1.0      5504.0
# 25           0.5              143.602013             1.0      5504.0
# 26           0.5              143.602013             1.0      5504.0
# 27           0.5              143.602013             1.0      5504.0
# 28           0.5              143.602013             1.0      5504.0
# 29           0.5              143.602013             1.0      5504.0

# %% [markdown]
# ## Adding Occlusion in Time not in Samples

# %%
evaluation['Occlusion Duration(s)'] = evaluation['Occlusion Duration']*1/120

# %%
before_crash = evaluation[evaluation['Filter Crashed'] == 0]
after_crash = evaluation[evaluation['Filter Crashed'] == 1].reset_index()

# %%
before_crash
# Out:
#     Unnamed: 0  index  Mean Squared Error  Mean Squared Error dB  \
# 0            0    0.0            0.000063             -42.006439
# 1            1    1.0            0.000095             -40.222714
# 2            2    2.0            0.000309             -35.101753
# 3            3    3.0            0.000787             -31.038408
# 4            4    4.0            0.001645             -27.837113
# 5            5    5.0            0.003019             -25.201847
# 6            6    6.0            0.004754             -23.229268
# 7            7    7.0            0.006593             -21.809378
# 8            8    8.0            0.008189             -20.867451
# 9            9    9.0            0.009185             -20.369430
# 10          10   10.0            0.009750             -20.110080
# 11          11   11.0            0.010582             -19.754157
# 12          12   12.0            0.012515             -19.025851
# 13          13   13.0            0.014872             -18.276410
# 14          14   14.0            0.018429             -17.345028
# 15          15   15.0            0.023097             -16.364419
#
#     Error in Filter Std  Occlusion Start  Occlusion End  Occlusion Duration  \
# 0             96.605889           1000.0         1000.0                 0.0
# 1             96.341013           1000.0         1300.0               300.0
# 2             95.922139           1000.0         1600.0               600.0
# 3             95.330787           1000.0         1900.0               900.0
# 4             94.240483           1000.0         2200.0              1200.0
# 5             94.203523           1000.0         2500.0              1500.0
# 6             93.328816           1000.0         2800.0              1800.0
# 7             92.497228           1000.0         3100.0              2100.0
# 8             92.201552           1000.0         3400.0              2400.0
# 9             92.029075           1000.0         3700.0              2700.0
# 10            92.041395           1000.0         4000.0              3000.0
# 11            92.041395           1000.0         4300.0              3300.0
# 12            92.041395           1000.0         4600.0              3600.0
# 13            91.628681           1000.0         4900.0              3900.0
# 14            92.047555           1000.0         5200.0              4200.0
# 15            92.029075           1000.0         5500.0              4500.0
#
#     System Noise  Meaned Filter Variance  Filter Crashed  Crashed At  \
# 0            0.5                0.001878             0.0         0.0
# 1            0.5                0.002197             0.0         0.0
# 2            0.5                0.003157             0.0         0.0
# 3            0.5                0.005059             0.0         0.0
# 4            0.5                0.008418             0.0         0.0
# 5            0.5                0.013991             0.0         0.0
# 6            0.5                0.022814             0.0         0.0
# 7            0.5                0.036216             0.0         0.0
# 8            0.5                0.056628             0.0         0.0
# 9            0.5                0.087987             0.0         0.0
# 10           0.5                0.138544             0.0         0.0
# 11           0.5                0.229947             0.0         0.0
# 12           0.5                0.419305             0.0         0.0
# 13           0.5                0.769025             0.0         0.0
# 14           0.5                1.152277             0.0         0.0
# 15           0.5                6.116453             0.0         0.0
#
#     Occlusion Duration(s)
# 0                     0.0
# 1                     2.5
# 2                     5.0
# 3                     7.5
# 4                    10.0
# 5                    12.5
# 6                    15.0
# 7                    17.5
# 8                    20.0
# 9                    22.5
# 10                   25.0
# 11                   27.5
# 12                   30.0
# 13                   32.5
# 14                   35.0
# 15                   37.5

# %%
after_crash
# Out:
#     level_0  Unnamed: 0  index  Mean Squared Error  Mean Squared Error dB  \
# 0        16          16   16.0            0.040419             -13.934181
# 1        17          17   17.0            0.040419             -13.934181
# 2        18          18   18.0            0.040419             -13.934181
# 3        19          19   19.0            0.040419             -13.934181
# 4        20          20   20.0            0.040419             -13.934181
# 5        21          21   21.0            0.040419             -13.934181
# 6        22          22   22.0            0.040419             -13.934181
# 7        23          23   23.0            0.040419             -13.934181
# 8        24          24   24.0            0.040419             -13.934181
# 9        25          25   25.0            0.040419             -13.934181
# 10       26          26   26.0            0.040419             -13.934181
# 11       27          27   27.0            0.040419             -13.934181
# 12       28          28   28.0            0.040419             -13.934181
# 13       29          29   29.0            0.040419             -13.934181
#
#     Error in Filter Std  Occlusion Start  Occlusion End  Occlusion Duration  \
# 0             27.202168           1000.0         5800.0              4800.0
# 1             27.202168           1000.0         6100.0              5100.0
# 2             27.202168           1000.0         6400.0              5400.0
# 3             27.202168           1000.0         6700.0              5700.0
# 4             27.202168           1000.0         7000.0              6000.0
# 5             27.202168           1000.0         7300.0              6300.0
# 6             27.202168           1000.0         7600.0              6600.0
# 7             27.202168           1000.0         7900.0              6900.0
# 8             27.202168           1000.0         8200.0              7200.0
# 9             27.202168           1000.0         8500.0              7500.0
# 10            27.202168           1000.0         8800.0              7800.0
# 11            27.202168           1000.0         9100.0              8100.0
# 12            27.202168           1000.0         9400.0              8400.0
# 13            27.202168           1000.0         9700.0              8700.0
#
#     System Noise  Meaned Filter Variance  Filter Crashed  Crashed At  \
# 0            0.5              143.602013             1.0      5504.0
# 1            0.5              143.602013             1.0      5504.0
# 2            0.5              143.602013             1.0      5504.0
# 3            0.5              143.602013             1.0      5504.0
# 4            0.5              143.602013             1.0      5504.0
# 5            0.5              143.602013             1.0      5504.0
# 6            0.5              143.602013             1.0      5504.0
# 7            0.5              143.602013             1.0      5504.0
# 8            0.5              143.602013             1.0      5504.0
# 9            0.5              143.602013             1.0      5504.0
# 10           0.5              143.602013             1.0      5504.0
# 11           0.5              143.602013             1.0      5504.0
# 12           0.5              143.602013             1.0      5504.0
# 13           0.5              143.602013             1.0      5504.0
#
#     Occlusion Duration(s)
# 0                    40.0
# 1                    42.5
# 2                    45.0
# 3                    47.5
# 4                    50.0
# 5                    52.5
# 6                    55.0
# 7                    57.5
# 8                    60.0
# 9                    62.5
# 10                   65.0
# 11                   67.5
# 12                   70.0
# 13                   72.5

# %% [markdown]
# ## Plotting Data
# Plotting Mean Squared Error per Occlusion

# %%
#plt.figure(figsize=(10, 10))
plt.title("Mean Squared Error per Occlusion Duration")
plt.plot(before_crash["Occlusion Duration(s)"], before_crash["Mean Squared Error dB"], marker='o', label="completed kalman filtering")
plt.plot(after_crash["Occlusion Duration(s)"], after_crash["Mean Squared Error dB"], marker='o', color="red", label="aborted kalman filtering")
plt.xlabel("Occlusion Duration (s)")
plt.legend()
# before crash
'''for i,p in enumerate(zip(before_crash["Occlusion Duration(s)"].values,before_crash["Mean Squared Error dB"].values)):
    print(i,p)
    label = "{:.2f} dB".format(p[1])
    plt.annotate(label, # this is the text
                 (p[0],before_crash["Mean Squared Error"][i]), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(-10,20), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

#after crash    

label = "{:.2f} dB".format(after_crash['Mean Squared Error dB'][0])
plt.annotate(label, # this is the text
            (after_crash['Occlusion Duration(s)'][0],after_crash["Mean Squared Error"][0]), # these are the coordinates to position the label
            textcoords="offset points", # how to position the text
            xytext=(0,-20), # distance from text to points (x,y)
            ha='center') # horizontal alignment can be left, right or center

'''
plt.grid()
plt.show()

# %% [markdown]
# Plotting Meaned Filter Variance per Occlusion

# %%
plt.figure(figsize=(20, 10))
plt.title("Mean Filter Variance per Occlusion Duration")
plt.plot(evaluation["Occlusion Duration(s)"], evaluation["Meaned Filter Variance"], marker='o')
plt.xlabel("Occlusion Duration (s)")

for x,y in zip(evaluation["Occlusion Duration(s)"].values,evaluation["Meaned Filter Variance"].values):
    label = "{:.2f} ".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center


plt.show()
