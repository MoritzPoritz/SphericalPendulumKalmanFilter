# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Dataset

# %%
evaluation = pd.read_csv("../src/data/Evaluation_21_02_2022_17_41_47.csv")

# %% [markdown]
# # Inspecting Dataset

# %%
evaluation
# Out:
#     Unnamed: 0  index  Mean Squared Error  Mean Squared Error dB  \
# 0            0    0.0            0.000475             -33.228992
# 1            1    1.0            0.000528             -32.777526
# 2            2    2.0            0.000787             -31.041027
# 3            3    3.0            0.001374             -28.620931
# 4            4    4.0            0.002418             -26.165595
# 5            5    5.0            0.003983             -23.997472
# 6            6    6.0            0.005784             -22.377970
# 7            7    7.0            0.007437             -21.286171
# 8            8    8.0            0.008732             -20.588827
# 9            9    9.0            0.009838             -20.071143
# 10          10   10.0            0.011430             -19.419353
# 11          11   11.0            0.014296             -18.447821
# 12          12   12.0            0.018328             -17.368740
# 13          13   13.0            0.022718             -16.436270
# 14          14   14.0            0.029606             -15.286228
# 15          15   15.0            0.035166             -14.538797
# 16          16   16.0            0.053667             -12.702896
# 17          17   17.0            0.053667             -12.702896
# 18          18   18.0            0.053667             -12.702896
# 19          19   19.0            0.053667             -12.702896
# 20          20   20.0            0.053667             -12.702896
# 21          21   21.0            0.053667             -12.702896
# 22          22   22.0            0.053667             -12.702896
# 23          23   23.0            0.053667             -12.702896
# 24          24   24.0            0.053667             -12.702896
# 25          25   25.0            0.053667             -12.702896
# 26          26   26.0            0.053667             -12.702896
# 27          27   27.0            0.053667             -12.702896
# 28          28   28.0            0.053667             -12.702896
# 29          29   29.0            0.053667             -12.702896
#
#     Error in Filter Std  Occlusion Start  Occlusion End  Occlusion Duration  \
# 0             84.643341           1000.0         1000.0                 0.0
# 1             84.501663           1000.0         1300.0               300.0
# 2             84.427744           1000.0         1600.0               600.0
# 3             83.897992           1000.0         1900.0               900.0
# 4             83.355920           1000.0         2200.0              1200.0
# 5             82.856967           1000.0         2500.0              1500.0
# 6             81.822102           1000.0         2800.0              1800.0
# 7             82.179377           1000.0         3100.0              2100.0
# 8             82.031539           1000.0         3400.0              2400.0
# 9             82.462733           1000.0         3700.0              2700.0
# 10            82.462733           1000.0         4000.0              3000.0
# 11            82.444253           1000.0         4300.0              3300.0
# 12            82.727609           1000.0         4600.0              3600.0
# 13            83.017125           1000.0         4900.0              3900.0
# 14            83.399039           1000.0         5200.0              4200.0
# 15            84.353825           1000.0         5500.0              4500.0
# 16            26.074905           1000.0         5800.0              4800.0
# 17            26.074905           1000.0         6100.0              5100.0
# 18            26.074905           1000.0         6400.0              5400.0
# 19            26.074905           1000.0         6700.0              5700.0
# 20            26.074905           1000.0         7000.0              6000.0
# 21            26.074905           1000.0         7300.0              6300.0
# 22            26.074905           1000.0         7600.0              6600.0
# 23            26.074905           1000.0         7900.0              6900.0
# 24            26.074905           1000.0         8200.0              7200.0
# 25            26.074905           1000.0         8500.0              7500.0
# 26            26.074905           1000.0         8800.0              7800.0
# 27            26.074905           1000.0         9100.0              8100.0
# 28            26.074905           1000.0         9400.0              8400.0
# 29            26.074905           1000.0         9700.0              8700.0
#
#     System Noise  Meaned Filter Variance  Filter Crashed
# 0            0.5            1.202301e-02             0.0
# 1            0.5            1.237567e-02             0.0
# 2            0.5            1.340638e-02             0.0
# 3            0.5            1.548361e-02             0.0
# 4            0.5            1.924078e-02             0.0
# 5            0.5            2.530827e-02             0.0
# 6            0.5            3.487269e-02             0.0
# 7            0.5            4.963688e-02             0.0
# 8            0.5            7.191746e-02             0.0
# 9            0.5            1.054907e-01             0.0
# 10           0.5            1.631155e-01             0.0
# 11           0.5            2.681563e-01             0.0
# 12           0.5            4.836140e-01             0.0
# 13           0.5            8.288073e-01             0.0
# 14           0.5            1.238367e+00             0.0
# 15           0.5            2.172649e+00             0.0
# 16           0.5            9.596022e+07             1.0
# 17           0.5            9.596022e+07             1.0
# 18           0.5            9.596022e+07             1.0
# 19           0.5            9.596022e+07             1.0
# 20           0.5            9.596022e+07             1.0
# 21           0.5            9.596022e+07             1.0
# 22           0.5            9.596022e+07             1.0
# 23           0.5            9.596022e+07             1.0
# 24           0.5            9.596022e+07             1.0
# 25           0.5            9.596022e+07             1.0
# 26           0.5            9.596022e+07             1.0
# 27           0.5            9.596022e+07             1.0
# 28           0.5            9.596022e+07             1.0
# 29           0.5            9.596022e+07             1.0

# %% [markdown]
# ## Adding Occlusion in Time not in Samples

# %%
evaluation['Occlusion Duration(s)'] = evaluation['Occlusion Duration']*1/120

# %% [markdown]
# ## Plotting Data
# Plotting Mean Squared Error per Occlusion

# %%
#plt.figure(figsize=(10, 5))
plt.title("Mean Squared Error per Occlusion Duration")
plt.plot(evaluation["Occlusion Duration(s)"], evaluation["Mean Squared Error"], marker='o')
plt.xlabel("Occlusion Duration (s)")

for x,y in zip(evaluation["Occlusion Duration(s)"].values,evaluation["Mean Squared Error dB"].values):
    label = "{:.2f} dB".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center


plt.show()

# %% [markdown]
# Plotting Meaned Filter Variance per Occlusion

# %%
plt.figure(figsize=(20, 10))
plt.title("Mean Filter Variance per Occlusion Duration")
plt.plot(evaluation["Occlusion Duration(s)"], evaluation["Meaned Filter Variance"], marker='o')
plt.xlabel("Occlusion Duration (s)")

for x,y in zip(evaluation["Occlusion Duration(s)"].values,evaluation["Meaned Filter Variance"].values):
    label = "{:.2f} ".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center


plt.show()
